# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns

# %%
df = pd.read_csv('country_wise_latest.csv')

# %%
df[['Country/Region', 'WHO Region', 'Confirmed', 'Active', 'Deaths']].head()
# Out:
#   Country/Region             WHO Region  Confirmed  Active  Deaths
# 0    Afghanistan  Eastern Mediterranean      36263    9796    1269
# 1        Albania                 Europe       4880    1991     144
# 2        Algeria                 Africa      27973    7973    1163
# 3        Andorra                 Europe        907      52      52
# 4         Angola                 Africa        950     667      41

# %%
df[df['Deaths']>10000].head()
# Out:
#    Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 23         Brazil    2442375   87618    1846641  508116      23284
# 61         France     220352   30212      81212  108928       2551
# 79          India    1480073   33408     951166  495499      44457
# 81           Iran     293606   15912     255144   22550       2434
# 85          Italy     246286   35112     198593   12581        168
#
#     New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 23         614          33728                3.59                  75.61
# 61          17            267               13.71                  36.86
# 79         637          33598                2.26                  64.26
# 81         212           1931                5.42                  86.90
# 85           5            147               14.26                  80.64
#
#     Deaths / 100 Recovered  Confirmed last week  1 week change  \
# ...

# %%
df[df['Deaths']>10000][['Country/Region', 'WHO Region', 'Confirmed', 'Active']].head()
# Out:
#    Country/Region             WHO Region  Confirmed  Active
# 23         Brazil               Americas    2442375  508116
# 61         France                 Europe     220352  108928
# 79          India        South-East Asia    1480073  495499
# 81           Iran  Eastern Mediterranean     293606   22550
# 85          Italy                 Europe     246286   12581

# %%
df[(df['Deaths']>1000) & (df['Active']<1000)]
# Out:
#    Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 83        Ireland      25892    1764      23364     764         11
#
#     New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 83           0              0                6.81                  90.24
#
#     Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 83                    7.55                25766            126
#
#     1 week % increase WHO Region
# 83               0.49     Europe

# %%
df[0:10]
# Out:
#         Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0          Afghanistan      36263    1269      25198    9796        106
# 1              Albania       4880     144       2745    1991        117
# 2              Algeria      27973    1163      18837    7973        616
# 3              Andorra        907      52        803      52         10
# 4               Angola        950      41        242     667         18
# 5  Antigua and Barbuda         86       3         65      18          4
# 6            Argentina     167416    3059      72575   91782       4890
# 7              Armenia      37390     711      26665   10014         73
# 8            Australia      15303     167       9311    5825        368
# 9              Austria      20558     713      18246    1599         86
#
#    New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0          10             18                3.50                  69.49
# ...

# %%
df[180:]
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 180           Venezuela      15988     146       9959    5883        525
# 181             Vietnam        431       0        365      66         11
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 180           4            213                0.91                  62.29
# 181           0              0                0.00                  84.69
# 182           2              0                0.73                  35.33
# 183           0              0               10.00                  80.00
# ...

# %%
len(df['Active'].unique())
# Out:
# 173

# %%
df['Active'].unique()
# Out:
# array([   9796,    1991,    7973,      52,     667,      18,   91782,
#          10014,    5825,    1599,    6781,     280,    3231,   97577,
#              9,    6221,   39154,      20,     699,      13,   47056,
#           5274,     674,  508116,       0,    4689,     121,      76,
#            756,      79,    2180,  107514,    2994,      37,   18782,
#           3258,  117163,      19,    2317,    2936,   11902,    5198,
#            806,      94,     189,    3715,     543,      24,   32869,
#          40733,   52992,    6849,    2178,      74,      42,    1257,
#           7933,     149,  108928,    2458,     252,     199,    7673,
#           3655,    2651,       1,   11093,     753,    1125,     188,
#           2817,   33536,     523,      21,  495499,   37292,   22550,
#          30983,     764,   36378,   12581,     129,    8174,     124,
#          29659,    9857,    3201,    8884,   10790,     143,    2122,
# ...

# %%
df['Active'].value_counts()
# Out:
# 0        5
# 1        3
# 2        3
# 1599     2
# 21       2
#         ..
# 7673     1
# 3655     1
# 2651     1
# 11093    1
# 2126     1
# Name: Active, Length: 173, dtype: int64

# %%
df.columns
# Out:
# Index(['Country/Region', 'Confirmed', 'Deaths', 'Recovered', 'Active',
#        'New cases', 'New deaths', 'New recovered', 'Deaths / 100 Cases',
#        'Recovered / 100 Cases', 'Deaths / 100 Recovered',
#        'Confirmed last week', '1 week change', '1 week % increase',
#        'WHO Region'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country/Region          187 non-null    object
#  1   Confirmed               187 non-null    int64
#  2   Deaths                  187 non-null    int64
#  3   Recovered               187 non-null    int64
#  4   Active                  187 non-null    int64
#  5   New cases               187 non-null    int64
#  6   New deaths              187 non-null    int64
#  7   New recovered           187 non-null    int64
#  8   Deaths / 100 Cases      187 non-null    float64
#  9   Recovered / 100 Cases   187 non-null    float64
#  10  Deaths / 100 Recovered  187 non-null    float64
#  11  Confirmed last week     187 non-null    int64
#  12  1 week change           187 non-null    int64
#  13  1 week % increase       187 non-null    float64
# ...

# %%
top = df.tail(10)
top
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 177      United Kingdom     301708   45844       1437  254427        688
# 178             Uruguay       1202      35        951     216         10
# 179          Uzbekistan      21209     121      11674    9414        678
# 180           Venezuela      15988     146       9959    5883        525
# 181             Vietnam        431       0        365      66         11
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 177           7              3               15.19                   0.48
# ...

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x=df['Country/Region'], y=df['Confirmed'])
# Out:
# <AxesSubplot:xlabel='Country/Region', ylabel='Confirmed'>
