# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns

# %%
df = pd.read_csv('data/country_wise_latest.csv').head()

# %%
print(df)
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 1        Albania       4880     144       2745    1991        117           6
# 2        Algeria      27973    1163      18837    7973        616           8
# 3        Andorra        907      52        803      52         10           0
# 4         Angola        950      41        242     667         18           1
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
# 2            749                4.16                  67.34
# 3              0                5.73                  88.53
# 4              0                4.32                  25.47
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# ...

# %%
df.min()
# Out:
# Country/Region            Afghanistan
# Confirmed                         907
# Deaths                             41
# Recovered                         242
# Active                             52
# New cases                          10
# New deaths                          0
# New recovered                       0
# Deaths / 100 Cases               2.95
# Recovered / 100 Cases           25.47
# Deaths / 100 Recovered           5.04
# Confirmed last week               749
# 1 week change                      23
# 1 week % increase                2.07
# WHO Region                     Africa
# dtype: object

# %%
df.max()
# Out:
# Country/Region            Angola
# Confirmed                  36263
# Deaths                      1269
# Recovered                  25198
# Active                      9796
# New cases                    616
# New deaths                    10
# New recovered                749
# Deaths / 100 Cases          5.73
# Recovered / 100 Cases      88.53
# Deaths / 100 Recovered     16.94
# Confirmed last week        35526
# 1 week change               4282
# 1 week % increase          26.84
# WHO Region                Europe
# dtype: object

# %%
df
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 1        Albania       4880     144       2745    1991        117           6
# 2        Algeria      27973    1163      18837    7973        616           8
# 3        Andorra        907      52        803      52         10           0
# 4         Angola        950      41        242     667         18           1
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
# 2            749                4.16                  67.34
# 3              0                5.73                  88.53
# 4              0                4.32                  25.47
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# ...

# %%
df[['Country/Region', 'WHO Region', 'Confirmed', 'Active', 'Deaths']]
# Out:
#   Country/Region             WHO Region  Confirmed  Active  Deaths
# 0    Afghanistan  Eastern Mediterranean      36263    9796    1269
# 1        Albania                 Europe       4880    1991     144
# 2        Algeria                 Africa      27973    7973    1163
# 3        Andorra                 Europe        907      52      52
# 4         Angola                 Africa        950     667      41

# %%
type(df['Country/Region'])
# Out:
# pandas.core.series.Series

# %%
df[['Country/Region', 'WHO Region', 'Confirmed', 'Active', 'Deaths']].max()
# Out:
# Country/Region    Angola
# WHO Region        Europe
# Confirmed          36263
# Active              9796
# Deaths              1269
# dtype: object

# %%
df[df['Deaths']>10000]
# Out:
# Empty DataFrame
# Columns: [Country/Region, Confirmed, Deaths, Recovered, Active, New cases, New deaths, New recovered, Deaths / 100 Cases, Recovered / 100 Cases, Deaths / 100 Recovered, Confirmed last week, 1 week change, 1 week % increase, WHO Region]
# Index: []

# %%
df.describe()
# Out:
#           Confirmed       Deaths     Recovered       Active  New cases  \
# count      5.000000     5.000000      5.000000     5.000000    5.00000
# mean   14194.600000   533.800000   9565.000000  4095.800000  173.40000
# std    16700.300156   625.167737  11625.016624  4473.928106  252.22371
# min      907.000000    41.000000    242.000000    52.000000   10.00000
# 25%      950.000000    52.000000    803.000000   667.000000   18.00000
# 50%     4880.000000   144.000000   2745.000000  1991.000000  106.00000
# 75%    27973.000000  1163.000000  18837.000000  7973.000000  117.00000
# max    36263.000000  1269.000000  25198.000000  9796.000000  616.00000
#
#        New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# count    5.000000       5.000000            5.000000               5.000000
# mean     5.000000     166.000000            4.132000              61.416000
# std      4.358899     326.922774            1.047172              23.206975
# ...

# %%
df.head()
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 1        Albania       4880     144       2745    1991        117           6
# 2        Algeria      27973    1163      18837    7973        616           8
# 3        Andorra        907      52        803      52         10           0
# 4         Angola        950      41        242     667         18           1
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
# 2            749                4.16                  67.34
# 3              0                5.73                  88.53
# 4              0                4.32                  25.47
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# ...

# %%
df[['Country/Region', 'WHO Region', 'Confirmed', 'Active', 'Deaths']].head()
# Out:
#   Country/Region             WHO Region  Confirmed  Active  Deaths
# 0    Afghanistan  Eastern Mediterranean      36263    9796    1269
# 1        Albania                 Europe       4880    1991     144
# 2        Algeria                 Africa      27973    7973    1163
# 3        Andorra                 Europe        907      52      52
# 4         Angola                 Africa        950     667      41

# %%
df = pd.read_csv('data/covid_19_clean_complete.csv')
print(df)
# Out:
#       Province/State         Country/Region        Lat       Long        Date  \
# 0                NaN            Afghanistan  33.939110  67.709953  2020-01-22
# 1                NaN                Albania  41.153300  20.168300  2020-01-22
# 2                NaN                Algeria  28.033900   1.659600  2020-01-22
# 3                NaN                Andorra  42.506300   1.521800  2020-01-22
# 4                NaN                 Angola -11.202700  17.873900  2020-01-22
# ...              ...                    ...        ...        ...         ...
# 49063            NaN  Sao Tome and Principe   0.186400   6.613100  2020-07-27
# 49064            NaN                  Yemen  15.552727  48.516388  2020-07-27
# 49065            NaN                Comoros -11.645500  43.333300  2020-07-27
# 49066            NaN             Tajikistan  38.861000  71.276100  2020-07-27
# 49067            NaN                Lesotho -29.610000  28.233600  2020-07-27
#
# ...

# %%
df[df['Deaths']>10000].head()
# Out:
#       Province/State Country/Region       Lat      Long        Date  \
# 17361            NaN          Italy  41.87194  12.56738  2020-03-28
# 17622            NaN          Italy  41.87194  12.56738  2020-03-29
# 17883            NaN          Italy  41.87194  12.56738  2020-03-30
# 18144            NaN          Italy  41.87194  12.56738  2020-03-31
# 18405            NaN          Italy  41.87194  12.56738  2020-04-01
#
#        Confirmed  Deaths  Recovered  Active WHO Region
# 17361      92472   10023      12384   70065     Europe
# 17622      97689   10779      13030   73880     Europe
# 17883     101739   11591      14620   75528     Europe
# 18144     105792   12428      15729   77635     Europe
# 18405     110574   13155      16847   80572     Europe

# %%
df[df['Deaths']>10000][['Country/Region', 'WHO Region', 'Confirmed', 'Active']].head()
# Out:
#       Country/Region WHO Region  Confirmed  Active
# 17361          Italy     Europe      92472   70065
# 17622          Italy     Europe      97689   73880
# 17883          Italy     Europe     101739   75528
# 18144          Italy     Europe     105792   77635
# 18405          Italy     Europe     110574   80572

# %%
df[(df['Deaths']>1000) & (df['Active']<1000)]
# Out:
#       Province/State Country/Region      Lat      Long        Date  Confirmed  \
# 18853          Hubei          China  30.9756  112.2707  2020-04-03      67802
# 19114          Hubei          China  30.9756  112.2707  2020-04-04      67803
# 19375          Hubei          China  30.9756  112.2707  2020-04-05      67803
# 19636          Hubei          China  30.9756  112.2707  2020-04-06      67803
# 19897          Hubei          China  30.9756  112.2707  2020-04-07      67803
# ...              ...            ...      ...       ...         ...        ...
# 48418            NaN        Ireland  53.1424   -7.6921  2020-07-25      25869
# 48607          Hubei          China  30.9756  112.2707  2020-07-26      68135
# 48679            NaN        Ireland  53.1424   -7.6921  2020-07-26      25881
# 48868          Hubei          China  30.9756  112.2707  2020-07-27      68135
# 48940            NaN        Ireland  53.1424   -7.6921  2020-07-27      25892
#
# ...

# %%
df[0:10]
# Out:
#                  Province/State       Country/Region       Lat        Long  \
# 0                           NaN          Afghanistan  33.93911   67.709953
# 1                           NaN              Albania  41.15330   20.168300
# 2                           NaN              Algeria  28.03390    1.659600
# 3                           NaN              Andorra  42.50630    1.521800
# 4                           NaN               Angola -11.20270   17.873900
# 5                           NaN  Antigua and Barbuda  17.06080  -61.796400
# 6                           NaN            Argentina -38.41610  -63.616700
# 7                           NaN              Armenia  40.06910   45.038200
# 8  Australian Capital Territory            Australia -35.47350  149.012400
# 9               New South Wales            Australia -33.86880  151.209300
#
#          Date  Confirmed  Deaths  Recovered  Active             WHO Region
# ...

# %%
df[180:]
# Out:
#       Province/State         Country/Region        Lat        Long  \
# 180              NaN            Philippines  12.879721  121.774017
# 181              NaN                 Poland  51.919400   19.145100
# 182              NaN               Portugal  39.399900   -8.224500
# 183              NaN                  Qatar  25.354800   51.183900
# 184              NaN                Romania  45.943200   24.966800
# ...              ...                    ...        ...         ...
# 49063            NaN  Sao Tome and Principe   0.186400    6.613100
# 49064            NaN                  Yemen  15.552727   48.516388
# 49065            NaN                Comoros -11.645500   43.333300
# 49066            NaN             Tajikistan  38.861000   71.276100
# 49067            NaN                Lesotho -29.610000   28.233600
#
#              Date  Confirmed  Deaths  Recovered  Active             WHO Region
# 180    2020-01-22          0       0          0       0        Western Pacific
# ...

# %%
len(df['Active'].unique())
# Out:
# 8641

# %%
df['Active'].unique()
# Out:
# array([   0,    1,   14, ..., 9414, 5883, 6791])

# %%
df['Active'].value_counts()
# Out:
# 0        14151
# 1         1792
# 2         1157
# 3         1027
# 5          757
#          ...
# 23182        1
# 10153        1
# 9054         1
# 61004        1
# 6791         1
# Name: Active, Length: 8641, dtype: int64

# %%
df.columns
# Out:
# Index(['Province/State', 'Country/Region', 'Lat', 'Long', 'Date', 'Confirmed',
#        'Deaths', 'Recovered', 'Active', 'WHO Region'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49068 entries, 0 to 49067
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Province/State  14664 non-null  object
#  1   Country/Region  49068 non-null  object
#  2   Lat             49068 non-null  float64
#  3   Long            49068 non-null  float64
#  4   Date            49068 non-null  object
#  5   Confirmed       49068 non-null  int64
#  6   Deaths          49068 non-null  int64
#  7   Recovered       49068 non-null  int64
#  8   Active          49068 non-null  int64
#  9   WHO Region      49068 non-null  object
# dtypes: float64(2), int64(4), object(4)
# memory usage: 3.7+ MB

# %%
top = df.tail(10)
top
# Out:
#                     Province/State         Country/Region        Lat  \
# 49058                          NaN                 Malawi -13.254300
# 49059  Falkland Islands (Malvinas)         United Kingdom -51.796300
# 49060    Saint Pierre and Miquelon                 France  46.885200
# 49061                          NaN            South Sudan   6.877000
# 49062                          NaN         Western Sahara  24.215500
# 49063                          NaN  Sao Tome and Principe   0.186400
# 49064                          NaN                  Yemen  15.552727
# 49065                          NaN                Comoros -11.645500
# 49066                          NaN             Tajikistan  38.861000
# 49067                          NaN                Lesotho -29.610000
#
#             Long        Date  Confirmed  Deaths  Recovered  Active  \
# 49058  34.301500  2020-07-27       3664      99       1645    1920
# 49059 -59.523600  2020-07-27         13       0         13       0
# ...
